# %% [markdown]
# # Scraping craigslist

# %% [markdown]
# ## Lecture objectives
#
# 1. Explore scraping more complex web pages
# 2. Show how to use classes to extract web content

# %% [markdown]
# ## Example: Scraping craigslist data
# Craiglist provides a wealth of information on apartment rentals and other types of housing, as you can read about in the [Boeing and Waddell paper](https://journals.sagepub.com/doi/abs/10.1177/0739456X16664789). But short of clicking through lots of links, how do we access it?
#
# As with any scraping project, the first step is to get an example web page, and see if we can reverse-engineer the structure.
#
# One option is to parse each detailed post, with information on parking, desired qualities of roommates, etc. But a lot of information is actually in the [list of posts](https://losangeles.craigslist.org/search/apa#search=1~list~0~0).
#
# Until late 2022, it was a pretty straightforward process to use `requests` to retrieve the list of posts. However, craigslist recently changed their web pages to use JavaScript, which means that the method using `requests` no longer works. There are workarounds, but to keep things simple, let's just download it to our computer using a web browser. This is a great illustration of some of the hazards of web scraping - there is no guarantee that the website owner won't suddenly change the structure on you!
#
# In Chrome, you download as a "web page, complete." That will give you a `html` document and a folder with other files. You'll just need the `html` file, which I saved to our git repository as `cl_posts.html`.
#
# We can open the file in Python using the `read()` function.

# %%
from bs4 import BeautifulSoup

with open('../data/cl_posts.html', 'r') as f:  
    saved_content = f.read()
        
soup = BeautifulSoup(saved_content, features='html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0062)https://losangeles.craigslist.org/search/apa#search=1~list~0~0 -->
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="craigslist" property="og:site_name"/>
#   <meta content="preview" name="twitter:card"/>
#   <meta content="los angeles apartments / housing for rent - craigslist" property="og:title"/>
#   <meta content="los angeles apartments / housing for rent - craigslist" name="description"/>
#   <meta content="los angeles apartments / housing for rent - craigslist" property="og:description"/>
#   <meta content="https://losangeles.craigslist.org/search/apa" property="og:url"/>
#   <title>
#    los angeles apartments / housing for rent - craigslist
#   </title>
#   <link href="https://losangeles.craigslist.org/search/apa" rel="canonical"/>
#   <style type="text/css">
#    body {
#             font-family: sans-serif;
#         }
#
#         #no-js {
#             position: fixed;
#             z-index: 100000;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             overflow:auto;
#             margin: 0;
#             background: transparent;
#         }
#
#         #no-js h1 {
#             margin: 0;
#             padding: .5em;
#             color: #00E;
#             background-color: #cccccc;
#         }
#
#         #no-js  p {
#             margin: 1em;
#         }
#
#         .no-js header,
#         .no-js form,
#         .no-js .tsb,
#         .unsupported-browser header,
#         .unsupported-browser form,
#         .unsupported-browser .tsb {
#             display: none;
#         }
#
#         #curtain {
#             display: none;
#             position: fixed;
#             z-index: 9000;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#             background: transparent;
#         }
#
#         .show-curtain #curtain {
#             display: block;
#         }
#
#         #curtain .cover,
#         #curtain .content {
#             position: absolute;
#             display: block;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#         }
#
#         #curtain .cover {
#             z-index: 1;
#             background-color: white;
#         }
#
#         .show-curtain #curtain .cover {
#             opacity: 0.7;
#         }
#
#         .show-curtain.clear #curtain .cover {
#             opacity: 0;
#         }
#
#         .show-curtain.opaque #curtain .cover {
#             opacity: 1;
#         }
#
#         #curtain .content {
#             z-index: 2;
#             background: transparent;
#             color: #00E;
#
#             display: flex;
#             flex-direction: column;
#             justify-content: center;
#             align-items: center;
#         }
#
#         .unrecoverable #curtain .content,
#         .unsupported-browser #curtain .content {
#             display: block;
#             align-items: start;
#         }
#
#         #curtain h1 {
#             margin: 0;
#             padding: .5em;
#             background-color: #cccccc;
#         }
#
#         #curtain  p {
#             margin: 1em;
#             color: black;
#         }
#
#         .pacify #curtain .icom-:after {
#             content: "\eb23";
#         }
#
#         #curtain .text {
#             display: none;
#         }
#
#         .loading #curtain .text.loading,
#         .reading #curtain .text.reading,
#         .writing #curtain .text.writing,
#         .saving #curtain .text.saving,
#         .searching #curtain .text.searching,
#         .unrecoverable #curtain .text.unrecoverable,
#         .message #curtain .text.message {
#             display: block;
#         }
#
#         .unrecoverable #curtain .text.unrecoverable {
#         }
#
#         @keyframes rotate {
#             from {
#                 transform: rotate(0deg);
#             }
#             to {
#                 transform: rotate(359deg);
#             }
#         }
#
#         .pacify #curtain .icom- {
#             font-size: 3em;
#             animation: rotate 2s infinite linear;
#         }
#   </style>
#   <script crossorigin="anonymous" src="./los angeles apartments _ housing for rent - craigslist_files/manifest.js" type="text/javascript">
#   </script>
#   <link href="./los angeles apartments _ housing for rent - craigslist_files/www-2023-01-26-12-19-f8e68460e498b24c83d1cb575921106400eb4aaf.css" rel="stylesheet" type="text/css"/>
#   <script crossorigin="anonymous" src="./los angeles apartments _ housing for rent - craigslist_files/search-2023-01-26-12-19-e052c83ed667a5046c1c08f1727f2d56d4f8b178.js" type="text/javascript">
#   </script>
#   <script src="./los angeles apartments _ housing for rent - craigslist_files/bbe8a523a089547e594fa2f101021699a377645c.js">
#   </script>
#   <script>
#    window.cl.init(
#              'https://www.craigslist.org/static/www/',
#              '',
#              'www',
#              'search',
#              {
# areaAbbrev: "lax",
# areaCoords: ["34.052200","-118.242996"],
# areaId: "7",
# areaName: "los angeles",
# defaultLocale: "en_US",
# initialCategoryAbbr: "apa",
# location: {"country":"US","radius":1,"lat":34.052,"region":"CA","postal":"90072","areaId":7,"city":"Los Angeles","url":"losangeles.craigslist.org","lon":-118.243},
# nearbyAreas: [{"name":"orange co","host":"orangecounty"},{"name":"inland empire","host":"inlandempire"},{"name":"ventura","host":"ventura"},{"name":"santa barbara","host":"santabarbara"},{"name":"palm springs","host":"palmsprings"},{"name":"bakersfield","host":"bakersfield"},{"name":"san diego","host":"sandiego"},{"name":"santa maria","host":"santamaria"},{"name":"san luis obispo","host":"slo"},{"name":"visalia-tulare","host":"visalia"},{"name":"imperial co","host":"imperial"},{"name":"hanford","host":"hanford"},{"name":"fresno","host":"fresno"},{"name":"yuma","host":"yuma"},{"name":"las vegas","host":"lasvegas"}],
# subareas: [{"abbr":"wst","name":"westside-southbay","id":"1"},{"abbr":"sfv","name":"SF valley","id":"2"},{"abbr":"lac","name":"central LA","id":"3"},{"abbr":"sgv","name":"san gabriel valley","id":"4"},{"abbr":"lgb","name":"long beach","id":"5"},{"abbr":"ant","name":"antelope valley","id":"6"}]
# },
#              0
#          );
#   </script>
#   <script>
#    window.cl.specialCurtainMessages = {
#             unsupportedBrowser: [
#                 "We've detected you are using a browser that is missing critical features.",
#                 "Please visit craigslist from a modern browser."
#             ],
#             unrecoverableError: [
#                 "There was an error loading the page."
#             ]
#         };
#   </script>
#   <style>
#   </style>
#  </head>
#  <body class="bd-can-hover cl-not-small-device cl-landscape">
#   <iframe id="cl-local-storage" src="./los angeles apartments _ housing for rent - craigslist_files/localStorage-092e9f9e2f09450529e744902aa7cdb3a5cc868d.html" style="display:none;">
#   </iframe>
#   <div class="cl-content">
#    <header class="cl-area-search no-faves cl-wide cl-expanded" style="top: 0px; left: 0px; right: 0px; position: fixed; z-index: 6000;">
#     <div class="cl-left-group">
#      <a class="bd-anchor text-only cl-header-logo" href="https://losangeles.craigslist.org/" tabindex="0">
#       <span class="label">
#        CL
#       </span>
#      </a>
#      <div class="cl-breadcrumb area-selector bd-combo-box static bd-vStat-valid" style="width: 120.391px;" tabindex="0">
#       <div class="bd-posit-box">
#        <button class="bd-button" tabindex="0">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          los angeles
#         </span>
#        </button>
#       </div>
#       <span class="icon icom- arrow bd-arrow-down">
#       </span>
#      </div>
#      <div class="cl-breadcrumb subarea-selector bd-combo-box static bd-vStat-valid" style="width: 139.062px;" tabindex="0">
#       <div class="bd-posit-box">
#        <button class="bd-button" tabindex="0">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          all los angeles
#         </span>
#        </button>
#       </div>
#       <span class="icon icom- arrow bd-arrow-down">
#       </span>
#      </div>
#      <button class="bd-button text-only cl-breadcrumb location-picker-crumb link-like" tabindex="0" type="button">
#       <span>
#       </span>
#      </button>
#      <div class="cl-breadcrumb section-selector bd-combo-box static bd-vStat-valid" style="width: 94.25px;" tabindex="0">
#       <div class="bd-posit-box">
#        <button class="bd-button hhh" tabindex="0">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          housing
#         </span>
#        </button>
#       </div>
#       <span class="icon icom- arrow bd-arrow-down">
#       </span>
#      </div>
#      <div class="cl-breadcrumb category-selector bd-combo-box static bd-vStat-valid" style="width: 195.641px;" tabindex="0">
#       <div class="bd-posit-box">
#        <button class="bd-button apa" tabindex="0">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          apartments / housing for rent
#         </span>
#        </button>
#       </div>
#       <span class="icon icom- arrow bd-arrow-down">
#       </span>
#      </div>
#      <div class="cl-static-breadcrumbs">
#       <div>
#        <span class="breadcrumb-location">
#         los angeles
#        </span>
#        <span class="icom- breadcrumb-separator">
#        </span>
#       </div>
#       <span class="breadcrumb-category">
#        apartments / housing for rent
#       </span>
#      </div>
#     </div>
#     <div class="cl-middle-group">
#     </div>
#     <div class="cl-right-group">
#      <div class="cl-menu-item cl-favorites">
#       <button class="bd-button cl-favorites-button empty" tabindex="0" type="button">
#        <span class="icon icom-">
#        </span>
#        <span class="label">
#         no favorites
#        </span>
#       </button>
#      </div>
#      <div class="cl-menu-item cl-banished">
#       <button class="bd-button cl-banished-button" tabindex="0" type="button">
#        <span class="icon icom-">
#        </span>
#        <span class="label">
#         1 hidden
#        </span>
#       </button>
#      </div>
#      <div class="cl-menu-item cl-goto-post">
#       <button class="bd-button text-only cl-goto-post link-like" tabindex="0" type="button">
#        <span>
#         post
#        </span>
#       </button>
#      </div>
#      <div class="cl-menu-item cl-goto-account">
#       <button class="bd-button text-only cl-goto-account link-like" tabindex="0" type="button">
#        <span>
#         account
#        </span>
#       </button>
#      </div>
#      <button class="bd-button icon-only cl-toggle-header" tabindex="0" title="close menu" type="button">
#       <span class="icon icom-">
#       </span>
#      </button>
#     </div>
#    </header>
#    <main class="cl-search cl-search-sort-mode-newest cl-show-filters cl-wide section-hhh category-apa cl-search-view-mode-list" style="margin-top: 98px; margin-left: 200px; margin-right: 0px; position: static;">
#     <div>
#     </div>
#     <form class="cl-search-query">
#      <div class="cl-query-bar" style="transition: top 0.5s ease 0s; top: 44px; left: 200px; right: 0px; z-index: 6000; position: fixed;">
#       <div class="cl-query-with-search-suggest bd-combo-box bd-vStat-valid empty" tabindex="0">
#        <div class="bd-posit-box">
#         <div class="decoration cl-search">
#          <span class="icom-">
#          </span>
#         </div>
#         <input autocomplete="off" enterkeyhint="search" placeholder="search apartments / housing for rent" tabindex="0"/>
#        </div>
#       </div>
#       <button class="bd-button cl-exec-search icon-only" tabindex="0" type="submit">
#        <span class="icon icom-">
#        </span>
#        <span class="label">
#         refresh results with search filters
#        </span>
#       </button>
#       <button class="bd-button cl-show-search-menu icon-only" tabindex="0" type="button">
#        <span class="icon icom-">
#        </span>
#        <span class="label">
#         open search menu
#        </span>
#       </button>
#      </div>
#      <div class="cl-filter-buttons wide overflow-none" style="transition: top 0.5s ease 0s;">
#       <div>
#        <div class="buttons" id="clComponentFilterButtons">
#         <button class="bd-button" tabindex="0" type="button">
#          <span class="icon icom-">
#          </span>
#          <span class="label">
#           price
#          </span>
#         </button>
#         <button class="bd-button" tabindex="0" type="button">
#          <span class="icon icom-">
#          </span>
#          <span class="label">
#           beds
#          </span>
#         </button>
#         <button class="bd-button" tabindex="0" type="button">
#          <span class="icon icom-">
#          </span>
#          <span class="label">
#           baths
#          </span>
#         </button>
#         <button class="bd-button" tabindex="0" type="button">
#          <span class="icon icom-">
#          </span>
#          <span class="label">
#           type
#          </span>
#         </button>
#         <button class="bd-button" tabindex="0" type="button">
#          <span class="icon icom-">
#          </span>
#          <span class="label">
#           cats ok
#          </span>
#         </button>
#         <button class="bd-button" tabindex="0" type="button">
#          <span class="icon icom-">
#          </span>
#          <span class="label">
#           dogs ok
#          </span>
#         </button>
#         <button class="bd-button" tabindex="0" type="button">
#          <span class="icon icom-">
#          </span>
#          <span class="label">
#           furnished
#          </span>
#         </button>
#         <button class="bd-button" tabindex="0" type="button">
#          <span class="icon icom-">
#          </span>
#          <span class="label">
#           +
#          </span>
#         </button>
#        </div>
#        <div class="icom- left-arrow">
#         
#        </div>
#        <div class="icom- right-arrow">
#         
#        </div>
#       </div>
#      </div>
#      <div class="cl-search-filters-panel" style="left: 0px; top: 44px; bottom: 0px; z-index: 6000; position: fixed;">
#       <div class="cl-title-bar">
#        <div class="back-and-title-links">
#         <div class="back-to-category">
#          <a>
#          </a>
#         </div>
#         <h1>
#          apartments / housing for rent
#         </h1>
#        </div>
#        <button class="bd-button cl-toggle icon-only" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#         </span>
#        </button>
#       </div>
#       <div class="cl-jsonform-filters-panel">
#        <div class="cl-jsonform-filter cl-jsonform-group jsonform-name-srchType-hasPic-postedToday-bundleDuplicates">
#         <label class="cl-jsonform-filter cl-jsonform-bool jsonform-name-srchType">
#          <input name="srchType" type="checkbox" value="T"/>
#          search titles only
#         </label>
#         <label class="cl-jsonform-filter cl-jsonform-bool jsonform-name-hasPic">
#          <input name="hasPic" type="checkbox" value="1"/>
#          has image
#         </label>
#         <label class="cl-jsonform-filter cl-jsonform-bool jsonform-name-postedToday">
#          <input name="postedToday" type="checkbox" value="1"/>
#          posted today
#         </label>
#         <label class="cl-jsonform-filter cl-jsonform-bool jsonform-name-bundleDuplicates">
#          <input name="bundleDuplicates" type="checkbox" value="1"/>
#          hide duplicates
#         </label>
#        </div>
#        <div class="cl-jsonform-filter cl-jsonform-location jsonform-name-search_distance-postal">
#         <div class="filter-label">
#          miles from location
#         </div>
#         <div class="widget-line">
#          <input class="small" placeholder="miles" type="tel"/>
#          <input class="small" name="postal" placeholder="from zip" type="tel"/>
#          <button class="bd-button icon-only sprite-target link-like" tabindex="0" type="button">
#           <span class="icon icom-">
#           </span>
#          </button>
#         </div>
#         <button class="bd-button text-only use-map link-like" tabindex="0" type="button">
#          <span>
#           use map...
#          </span>
#         </button>
#         <input name="search_distance" type="hidden" value=""/>
#        </div>
#        <input class="jsonform-name-vicinity" name="vicinity" type="hidden" value=""/>
#        <div class="jsonform-name-bar-chart-widget cl-jsonform-filter cl-jsonform-bar-chart-widget">
#         <div class="filter-label">
#          price
#         </div>
#         <a class="filter-clear-reset-button" style="display: none;">
#          clear
#         </a>
#         <a class="filter-clear-reset-button" style="display: none;">
#          reset
#         </a>
#         <input name="min_price" type="hidden" value=""/>
#         <input name="max_price" type="hidden" value=""/>
#         <div class="cl-bar-chart-widget">
#          <div class="cl-bar-chart-control">
#           <div class="input-fields">
#            <div class="range-inputs">
#             <span>
#              $
#             </span>
#             <input placeholder="min" type="text"/>
#             <span>
#              – $
#             </span>
#             <input placeholder="max" type="text"/>
#            </div>
#           </div>
#           <div class="chart-container" style="height: 110px; width: 185px;">
#            <svg class="bars" height="57" style="top: 28px;" width="155">
#             <rect class="bar" height="1.1948546927108146" width="10.083333333333334" x="5" y="55.80514530728919">
#             </rect>
#             <rect class="bar" height="0.162934730824202" width="10.083333333333334" x="17.083333333333336" y="56.837065269175795">
#             </rect>
#             <rect class="bar" height="1.222010481181515" width="10.083333333333334" x="29.166666666666668" y="55.77798951881849">
#             </rect>
#             <rect class="bar" height="3.4487851357789423" width="10.083333333333334" x="41.25" y="53.55121486422106">
#             </rect>
#             <rect class="bar" height="9.694616484040019" width="10.083333333333334" x="53.333333333333336" y="47.30538351595998">
#             </rect>
#             <rect class="bar" height="36.60600285850405" width="10.083333333333334" x="65.41666666666667" y="20.39399714149595">
#             </rect>
#             <rect class="bar" height="57" width="10.083333333333334" x="77.5" y="0">
#             </rect>
#             <rect class="bar" height="47.49547403525489" width="10.083333333333334" x="89.58333333333334" y="9.504525964745113">
#             </rect>
#             <rect class="bar" height="35.84564078132444" width="10.083333333333334" x="101.66666666666667" y="21.15435921867556">
#             </rect>
#             <rect class="bar" height="20.095283468318247" width="10.083333333333334" x="113.75" y="36.90471653168176">
#             </rect>
#             <rect class="bar" height="17.461171986660315" width="10.083333333333334" x="125.83333333333334" y="39.53882801333968">
#             </rect>
#             <rect class="bar" height="14.229633158646974" width="10.083333333333334" x="137.91666666666669" y="42.770366841353024">
#             </rect>
#            </svg>
#            <svg class="xaxis" height="110" width="155">
#             <defs>
#              <marker id="arrowhead" markerheight="7" markerwidth="10" orient="auto" refx="0" refy="3.5">
#               <polygon points="0 0, 10 3.5, 0 7">
#               </polygon>
#              </marker>
#             </defs>
#             <g transform="translate(5, 0)">
#              <g transform="translate(0, 85)">
#               <text class="tick" text-anchor="middle" y="16">
#                $0
#               </text>
#               <line class="tickmark" y1="0" y2="5">
#               </line>
#              </g>
#              <g transform="translate(38.35978835978836, 85)">
#               <text class="tick" text-anchor="middle" y="16">
#                $1k
#               </text>
#               <line class="tickmark" y1="0" y2="5">
#               </line>
#              </g>
#              <g transform="translate(76.71957671957672, 85)">
#               <text class="tick" text-anchor="middle" y="16">
#                $2k
#               </text>
#               <line class="tickmark" y1="0" y2="5">
#               </line>
#              </g>
#              <g transform="translate(115.07936507936508, 85)">
#               <text class="tick" text-anchor="middle" y="16">
#                $3k
#               </text>
#               <line class="tickmark" y1="0" y2="5">
#               </line>
#              </g>
#              <line class="arrowhead" marker-end="url(#arrowhead)" x1="0" x2="145" y1="85" y2="85">
#              </line>
#              <text class="abs-max-price" text-anchor="start" x="155" y="89">
#               $31.5k
#              </text>
#             </g>
#            </svg>
#            <svg class="average" height="110" width="155">
#             <text class="avg-text" text-anchor="middle" x="95.65430302998276" y="14">
#              avg: $2,363
#             </text>
#             <line class="line" stroke-dasharray="3,3" x1="95.65430302998276" x2="95.65430302998276" y1="20" y2="85">
#             </line>
#            </svg>
#            <svg class="sliders" height="85" width="155">
#             <rect class="selection" height="62.7" width="145" x="-995" y="22.299999999999997">
#             </rect>
#             <g class="handle left-handle" transform="translate(-995, 22.299999999999997)">
#              <rect class="grab-area" fill="transparent" height="62.7" width="20" x="-19">
#              </rect>
#              <line class="edge" y2="62.7">
#              </line>
#              <g transform="translate(0, 18.85)">
#               <path class="grab-handle" d="M0,0 L3,0 L4,1 L4,24 L3,25 L0,25  M2,4 L2,21">
#               </path>
#              </g>
#             </g>
#             <g class="handle right-handle" transform="translate(-850, 22.299999999999997)">
#              <rect class="grab-area" fill="transparent" height="62.7" width="20" x="-1">
#              </rect>
#              <line class="edge" y2="62.7">
#              </line>
#              <g transform="translate(0, 18.85)">
#               <path class="grab-handle" d="M0,0 L3,0 L4,1 L4,24 L3,25 L0,25  M2,4 L2,21">
#               </path>
#              </g>
#             </g>
#            </svg>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="cl-jsonform-filter cl-jsonform-range jsonform-name-min_bedrooms-max_bedrooms">
#         <div class="filter-label">
#          bedrooms
#         </div>
#         <div class="widget-line">
#          <input class="small" name="min_bedrooms" placeholder="min" title="whole number, no letters or symbols" type="tel"/>
#          <input class="small" name="max_bedrooms" placeholder="max" title="whole number, no letters or symbols" type="tel"/>
#         </div>
#        </div>
#        <div class="cl-jsonform-filter cl-jsonform-range jsonform-name-min_bathrooms-max_bathrooms">
#         <div class="filter-label">
#          bathrooms
#         </div>
#         <div class="widget-line">
#          <input class="small" name="min_bathrooms" placeholder="min" title="whole number, no letters or symbols" type="tel"/>
#          <input class="small" name="max_bathrooms" placeholder="max" title="whole number, no letters or symbols" type="tel"/>
#         </div>
#        </div>
#        <div class="cl-jsonform-filter cl-jsonform-range jsonform-name-minSqft-maxSqft">
#         <div class="filter-label">
#          sq ft
#         </div>
#         <div class="widget-line">
#          <input class="small" name="minSqft" placeholder="min" title="whole number, no letters or symbols" type="tel"/>
#          <input class="small" name="maxSqft" placeholder="max" title="whole number, no letters or symbols" type="tel"/>
#         </div>
#        </div>
#        <div class="cl-jsonform-filter cl-jsonform-group jsonform-name-pets_cat-pets_dog-is_furnished-no_smoking-wheelchaccess-airconditioning-ev_charging-application_fee-broker_fee">
#         <label class="cl-jsonform-filter cl-jsonform-bool jsonform-name-pets_cat">
#          <input name="pets_cat" type="checkbox" value="1"/>
#          cats ok
#         </label>
#         <label class="cl-jsonform-filter cl-jsonform-bool jsonform-name-pets_dog">
#          <input name="pets_dog" type="checkbox" value="1"/>
#          dogs ok
#         </label>
#         <label class="cl-jsonform-filter cl-jsonform-bool jsonform-name-is_furnished">
#          <input name="is_furnished" type="checkbox" value="1"/>
#          furnished
#         </label>
#         <label class="cl-jsonform-filter cl-jsonform-bool jsonform-name-no_smoking">
#          <input name="no_smoking" type="checkbox" value="1"/>
#          no smoking
#         </label>
#         <label class="cl-jsonform-filter cl-jsonform-bool jsonform-name-wheelchaccess">
#          <input name="wheelchaccess" type="checkbox" value="1"/>
#          wheelchair accessible
#         </label>
#         <label class="cl-jsonform-filter cl-jsonform-bool jsonform-name-airconditioning">
#          <input name="airconditioning" type="checkbox" value="1"/>
#          air conditioning
#         </label>
#         <label class="cl-jsonform-filter cl-jsonform-bool jsonform-name-ev_charging">
#          <input name="ev_charging" type="checkbox" value="1"/>
#          EV charging
#         </label>
#         <label class="cl-jsonform-filter cl-jsonform-bool jsonform-name-application_fee">
#          <input name="application_fee" type="checkbox" value="1"/>
#          no application fee
#         </label>
#         <label class="cl-jsonform-filter cl-jsonform-bool jsonform-name-broker_fee">
#          <input name="broker_fee" type="checkbox" value="1"/>
#          no broker fee
#         </label>
#        </div>
#        <div class="cl-jsonform-filter cl-jsonform-multi-select jsonform-name-rent_period collapsed no-items-selected show-all">
#         <button class="bd-button title link-like" tabindex="0" type="button">
#          <span class="icon icom-">
#          </span>
#          <span class="label">
#           rent period
#          </span>
#         </button>
#         <ul>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_1" name="rent_period" type="checkbox" value="1"/>
#           <label for="_1">
#            daily
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_2" name="rent_period" type="checkbox" value="2"/>
#           <label for="_2">
#            weekly
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_3" name="rent_period" type="checkbox" value="3"/>
#           <label for="_3">
#            monthly
#           </label>
#          </li>
#         </ul>
#        </div>
#        <select class="cl-jsonform-filter cl-jsonform-select jsonform-name-availabilityMode cl-jsonform-select" name="availabilityMode">
#         <option value="">
#          all dates
#         </option>
#         <option value="1">
#          within 30 days
#         </option>
#         <option value="2">
#          beyond 30 days
#         </option>
#        </select>
#        <div class="cl-jsonform-filter cl-jsonform-multi-select jsonform-name-housing_type collapsed no-items-selected show-all">
#         <button class="bd-button title link-like" tabindex="0" type="button">
#          <span class="icon icom-">
#          </span>
#          <span class="label">
#           housing type
#          </span>
#         </button>
#         <ul>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_4" name="housing_type" type="checkbox" value="1"/>
#           <label for="_4">
#            apartment
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_5" name="housing_type" type="checkbox" value="2"/>
#           <label for="_5">
#            condo
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_6" name="housing_type" type="checkbox" value="3"/>
#           <label for="_6">
#            cottage/cabin
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_7" name="housing_type" type="checkbox" value="4"/>
#           <label for="_7">
#            duplex
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_8" name="housing_type" type="checkbox" value="5"/>
#           <label for="_8">
#            flat
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_9" name="housing_type" type="checkbox" value="6"/>
#           <label for="_9">
#            house
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_10" name="housing_type" type="checkbox" value="7"/>
#           <label for="_10">
#            in-law
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_11" name="housing_type" type="checkbox" value="8"/>
#           <label for="_11">
#            loft
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_12" name="housing_type" type="checkbox" value="9"/>
#           <label for="_12">
#            townhouse
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_13" name="housing_type" type="checkbox" value="10"/>
#           <label for="_13">
#            manufactured
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_14" name="housing_type" type="checkbox" value="11"/>
#           <label for="_14">
#            assisted living
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_15" name="housing_type" type="checkbox" value="12"/>
#           <label for="_15">
#            land
#           </label>
#          </li>
#          <div class="select-deselect-all-button-group">
#           <button class="bd-button text-only select-all link-like" tabindex="0" type="button">
#            <span>
#             select all
#            </span>
#           </button>
#           <button class="bd-button text-only deselect-all link-like bd-disabled" tabindex="0" type="button">
#            <span>
#             deselect all
#            </span>
#           </button>
#          </div>
#         </ul>
#        </div>
#        <div class="cl-jsonform-filter cl-jsonform-multi-select jsonform-name-laundry collapsed no-items-selected show-all">
#         <button class="bd-button title link-like" tabindex="0" type="button">
#          <span class="icon icom-">
#          </span>
#          <span class="label">
#           laundry
#          </span>
#         </button>
#         <ul>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_16" name="laundry" type="checkbox" value="1"/>
#           <label for="_16">
#            w/d in unit
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_17" name="laundry" type="checkbox" value="4"/>
#           <label for="_17">
#            w/d hookups
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_18" name="laundry" type="checkbox" value="2"/>
#           <label for="_18">
#            laundry in bldg
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_19" name="laundry" type="checkbox" value="3"/>
#           <label for="_19">
#            laundry on site
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_20" name="laundry" type="checkbox" value="5"/>
#           <label for="_20">
#            no laundry on site
#           </label>
#          </li>
#         </ul>
#        </div>
#        <div class="cl-jsonform-filter cl-jsonform-multi-select jsonform-name-parking collapsed no-items-selected show-all">
#         <button class="bd-button title link-like" tabindex="0" type="button">
#          <span class="icon icom-">
#          </span>
#          <span class="label">
#           parking
#          </span>
#         </button>
#         <ul>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_21" name="parking" type="checkbox" value="1"/>
#           <label for="_21">
#            carport
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_22" name="parking" type="checkbox" value="2"/>
#           <label for="_22">
#            attached garage
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_23" name="parking" type="checkbox" value="3"/>
#           <label for="_23">
#            detached garage
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_24" name="parking" type="checkbox" value="4"/>
#           <label for="_24">
#            off-street parking
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_25" name="parking" type="checkbox" value="5"/>
#           <label for="_25">
#            street parking
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_26" name="parking" type="checkbox" value="6"/>
#           <label for="_26">
#            valet parking
#           </label>
#          </li>
#          <li class="checkbox">
#           <input class="multi-checkbox" id="_27" name="parking" type="checkbox" value="7"/>
#           <label for="_27">
#            no parking
#           </label>
#          </li>
#          <div class="select-deselect-all-button-group">
#           <button class="bd-button text-only select-all link-like" tabindex="0" type="button">
#            <span>
#             select all
#            </span>
#           </button>
#           <button class="bd-button text-only deselect-all link-like bd-disabled" tabindex="0" type="button">
#            <span>
#             deselect all
#            </span>
#           </button>
#          </div>
#         </ul>
#        </div>
#        <div class="cl-jsonform-filter cl-jsonform-date-picker jsonform-name-sale_date">
#         <div class="filter-label">
#          open house date
#         </div>
#         <table class="cl-calendar">
#          <tbody>
#           <tr class="day-header">
#            <td>
#             S
#            </td>
#            <td>
#             M
#            </td>
#            <td>
#             T
#            </td>
#            <td>
#             W
#            </td>
#            <td>
#             T
#            </td>
#            <td>
#             F
#            </td>
#            <td>
#             S
#            </td>
#           </tr>
#           <tr class="week">
#            <td class="disabled" data-date="2023-01-29">
#             29
#            </td>
#            <td class="today" data-date="2023-01-30">
#             30
#            </td>
#            <td data-date="2023-01-31">
#             31
#            </td>
#            <td data-date="2023-02-01">
#             1
#            </td>
#            <td data-date="2023-02-02">
#             2
#            </td>
#            <td data-date="2023-02-03">
#             3
#            </td>
#            <td data-date="2023-02-04">
#             4
#            </td>
#           </tr>
#           <tr class="week">
#            <td data-date="2023-02-05">
#             5
#            </td>
#            <td data-date="2023-02-06">
#             6
#            </td>
#            <td data-date="2023-02-07">
#             7
#            </td>
#            <td data-date="2023-02-08">
#             8
#            </td>
#            <td data-date="2023-02-09">
#             9
#            </td>
#            <td data-date="2023-02-10">
#             10
#            </td>
#            <td data-date="2023-02-11">
#             11
#            </td>
#           </tr>
#           <tr class="week">
#            <td data-date="2023-02-12">
#             12
#            </td>
#            <td data-date="2023-02-13">
#             13
#            </td>
#            <td data-date="2023-02-14">
#             14
#            </td>
#            <td data-date="2023-02-15">
#             15
#            </td>
#            <td data-date="2023-02-16">
#             16
#            </td>
#            <td data-date="2023-02-17">
#             17
#            </td>
#            <td data-date="2023-02-18">
#             18
#            </td>
#           </tr>
#           <tr class="week">
#            <td data-date="2023-02-19">
#             19
#            </td>
#            <td data-date="2023-02-20">
#             20
#            </td>
#            <td data-date="2023-02-21">
#             21
#            </td>
#            <td data-date="2023-02-22">
#             22
#            </td>
#            <td data-date="2023-02-23">
#             23
#            </td>
#            <td data-date="2023-02-24">
#             24
#            </td>
#            <td data-date="2023-02-25">
#             25
#            </td>
#           </tr>
#           <tr class="week">
#            <td data-date="2023-02-26">
#             26
#            </td>
#            <td data-date="2023-02-27">
#             27
#            </td>
#            <td data-date="2023-02-28">
#             28
#            </td>
#            <td data-date="2023-03-01">
#             1
#            </td>
#            <td data-date="2023-03-02">
#             2
#            </td>
#            <td data-date="2023-03-03">
#             3
#            </td>
#            <td data-date="2023-03-04">
#             4
#            </td>
#           </tr>
#          </tbody>
#         </table>
#         <input name="sale_date" type="hidden" value=""/>
#        </div>
#       </div>
#       <div class="spacer">
#       </div>
#       <div class="cl-command-buttons">
#        <button class="bd-button cl-exec-cancel label-only" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          cancel
#         </span>
#        </button>
#        <button class="bd-button cl-exec-resetSearch label-only bd-disabled" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          reset
#         </span>
#        </button>
#        <button class="bd-button cl-exec-search label-only" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          apply
#         </span>
#        </button>
#       </div>
#       <div class="cl-psa">
#        <a class="bd-anchor text-only aboutFha" href="https://www.craigslist.org/about/FHA" tabindex="0">
#         <span class="label">
#          fair housing
#         </span>
#        </a>
#        <a class="bd-anchor text-only safety" href="https://www.craigslist.org/about/safety" tabindex="0">
#         <span class="label">
#          safety tips
#         </span>
#        </a>
#        <a class="bd-anchor text-only aboutProhibited" href="https://www.craigslist.org/about/prohibited" tabindex="0">
#         <span class="label">
#          prohibited items
#         </span>
#        </a>
#        <a class="bd-anchor text-only aboutRecalledItems" href="https://www.craigslist.org/about/recalled_items" tabindex="0">
#         <span class="label">
#          product recalls
#         </span>
#        </a>
#        <a class="bd-anchor text-only scams" href="https://www.craigslist.org/about/scams" tabindex="0">
#         <span class="label">
#          avoiding scams
#         </span>
#        </a>
#       </div>
#       <div class="related-searches">
#        <div class="link-like">
#         <span>
#          ▸
#         </span>
#         <span hidden="">
#          ▾
#         </span>
#         <span class="label">
#          related searches
#         </span>
#        </div>
#        <ul hidden="">
#         <li>
#          <a href="https://losangeles.craigslist.org/search/one-bedroom-apartment">
#           one bedroom apartments for rent
#          </a>
#         </li>
#         <li>
#          <a href="https://losangeles.craigslist.org/search/two-bedroom-apartment">
#           two bedroom apartments for rent
#          </a>
#         </li>
#         <li>
#          <a href="https://losangeles.craigslist.org/search/furnished-apartment">
#           furnished apartments for rent
#          </a>
#         </li>
#         <li>
#          <a href="https://losangeles.craigslist.org/search/house-for-rent">
#           houses for rent
#          </a>
#         </li>
#         <li>
#          <a href="https://losangeles.craigslist.org/search/pet-friendly-apartment">
#           pet friendly apartments for rent
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </form>
#     <div class="cl-search-results">
#      <div class="no-day-pages cl-search-toolbars top cl-multi-column" id="search-toolbars-1">
#       <div class="cl-search-tools-left tool-container">
#        <div class="cl-search-view-mode bd-combo-box static bd-vStat-valid" style="width: 112.266px;" tabindex="0">
#         <div class="bd-posit-box">
#          <button class="bd-button cl-search-view-mode-list" tabindex="0">
#           <span class="icon icom-">
#           </span>
#           <span class="label">
#            list
#           </span>
#          </button>
#         </div>
#         <span class="icon icom- arrow bd-arrow-down">
#         </span>
#        </div>
#        <div class="cl-search-sort-mode bd-combo-box static bd-vStat-valid" style="width: 120.516px;" tabindex="0">
#         <div class="bd-posit-box">
#          <button class="bd-button cl-search-sort-mode-newest" tabindex="0">
#           <span class="icon icom-">
#           </span>
#           <span class="label">
#            newest
#           </span>
#          </button>
#         </div>
#         <span class="icon icom- arrow bd-arrow-down">
#         </span>
#        </div>
#        <div class="spacer">
#        </div>
#        <button class="bd-button cl-save-search" tabindex="0" title="save this search" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          save
#         </span>
#        </button>
#       </div>
#       <div class="cl-search-paginator">
#        <button class="bd-button cl-first-page icon-only bd-disabled" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          first page
#         </span>
#        </button>
#        <button class="bd-button cl-prev-page icon-only bd-disabled" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          previous page
#         </span>
#        </button>
#        <span class="cl-page-number">
#         1 - 120 of &gt;10,000
#        </span>
#        <button class="bd-button cl-next-page icon-only" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          next page
#         </span>
#        </button>
#        <button class="bd-button cl-last-page icon-only" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          last page
#         </span>
#        </button>
#       </div>
#       <div class="cl-search-day-paginator">
#        <button class="bd-button cl-prev-day-page icon-only" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          previous day
#         </span>
#        </button>
#        <span class="cl-page-date">
#        </span>
#        <button class="bd-button cl-next-day-page icon-only" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          next day
#         </span>
#        </button>
#       </div>
#       <div class="cl-search-map-info">
#        <div>
#         <span class="">
#          No mappable items found
#         </span>
#         <span class="zoom-out">
#         </span>
#        </div>
#       </div>
#       <div class="cl-search-tools-right tool-container">
#        <button class="bd-button cl-save-search" tabindex="0" title="save this search" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          save
#         </span>
#        </button>
#       </div>
#      </div>
#      <div class="cl-hub-links">
#       <div class="hublinks-content">
#        <h2>
#         see also
#        </h2>
#        <a class="hubLink-anchor" href="https://losangeles.craigslist.org/search/one-bedroom-apartment" tabindex="0">
#         <span class="label">
#          1-BR
#         </span>
#        </a>
#        <a class="hubLink-anchor" href="https://losangeles.craigslist.org/search/two-bedroom-apartment" tabindex="0">
#         <span class="label">
#          2-BR
#         </span>
#        </a>
#        <a class="hubLink-anchor" href="https://losangeles.craigslist.org/search/furnished-apartment" tabindex="0">
#         <span class="label">
#          furnished
#         </span>
#        </a>
#        <a class="hubLink-anchor" href="https://losangeles.craigslist.org/search/house-for-rent" tabindex="0">
#         <span class="label">
#          house for rent
#         </span>
#        </a>
#        <a class="hubLink-anchor" href="https://losangeles.craigslist.org/search/pet-friendly-apartment" tabindex="0">
#         <span class="label">
#          pet-friendly
#         </span>
#        </a>
#       </div>
#      </div>
#      <div class="bd-hidden cl-search-map no-mappable-results" id="search-map-1" style="display: none;">
#       <div class="top-right-button-group">
#        <button class="bd-button full-screen-button label-only" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          full screen
#         </span>
#        </button>
#        <button class="bd-button choose-location-button label-only bd-hidden" style="display: none;" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          search this region
#         </span>
#        </button>
#       </div>
#       <div class="map">
#       </div>
#      </div>
#      <div class="results cl-results-page cl-search-view-mode-list" id="search-results-page-1">
#       <ol>
#        <div class="result-count">
#         9,999 postings
#        </div>
#        <li class="cl-search-result cl-search-view-mode-list" title="1050 N. Orange Grove Ave./All Utilities Included!!!">
#         <div class="result-node-wide">
#          <button class="bd-button cl-favorite-button icon-only" tabindex="0" title="add to favorites list" type="button">
#           <span class="icon icom-">
#           </span>
#           <span class="label">
#           </span>
#          </button>
#          <a class="titlestring" href="https://losangeles.craigslist.org/wst/apa/d/west-hollywood-1050-orange-grove-ave/7584215293.html">
#           1050 N. Orange Grove Ave./All Utilities Included!!!
#          </a>
#          <span class="meta">
#           <span class="separator">
#            ·
#           </span>
#           West Hollywood
#           <span class="separator">
#            ·
#           </span>
#           <span title="Mon Jan 30 2023 11:59:56 GMT-0800 (Pacific Standard Time)">
#            5 minutes ago
#           </span>
#           <span class="separator">
#            ·
#           </span>
#           <span class="priceinfo">
#            $1,195
#           </span>
#           <span class="pic-button">
#            pic
#           </span>
#           <button class="bd-button cl-banish-button icon-only" tabindex="0" title="hide posting" type="button">
#            <span class="icon icom-">
#            </span>
#            <span class="label">
#            </span>
#           </button>
#          </span>
#         </div>
#        </li>
#        <li class="cl-search-result cl-search-view-mode-list" title="BEAUTIFUL DORMITORY STYLE HOUSING AVAILABLE - TORRANCE!">
#         <div class="result-node-wide">
#          <button class="bd-button cl-favorite-button icon-only" tabindex="0" title="add to favorites list" type="button">
#           <span class="icon icom-">
#           </span>
#           <span class="label">
#           </span>
#          </button>
#          <a class="titlestring" href="https://losangeles.craigslist.org/wst/apa/d/torrance-beautiful-dormitory-style/7579182659.html">
#           BEAUTIFUL DORMITORY STYLE HOUSING AVAILABLE - TORRANCE!
#          </a>
#          <span class="meta">
#           <span class="separator">
#            ·
#           </span>
#           westside-southbay-310
#           <span class="separator">
#            ·
#           </span>
# ...
#            <span class="post-bedrooms">
#             2br
#            </span>
#           </span>
#           <span class="separator">
#            ·
#           </span>
#           <span class="priceinfo">
#            $2,150
#           </span>
#           <span class="pic-button">
#            pic
#           </span>
#           <button class="bd-button cl-banish-button icon-only" tabindex="0" title="hide posting" type="button">
#            <span class="icon icom-">
#            </span>
#            <span class="label">
#            </span>
#           </button>
#          </span>
#         </div>
#        </li>
#        <li class="cl-search-result cl-search-view-mode-list" title="Creative Space/ Work Office ONLY!!!">
#         <div class="result-node-wide">
#          <button class="bd-button cl-favorite-button icon-only" tabindex="0" title="add to favorites list" type="button">
#           <span class="icon icom-">
#           </span>
#           <span class="label">
#           </span>
#          </button>
#          <a class="titlestring" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-creative-space-work-office/7576640436.html">
#           Creative Space/ Work Office ONLY!!!
#          </a>
#          <span class="meta">
#           <span class="separator">
#            ·
#           </span>
#           Arts District; Downtown Los Angeles
#           <span class="separator">
#            ·
#           </span>
#           <span title="Mon Jan 30 2023 11:48:36 GMT-0800 (Pacific Standard Time)">
#            16 minutes ago
#           </span>
#           <span class="separator">
#            ·
#           </span>
#           <span class="housing-meta">
#            <span class="post-sqft">
#             1200ft
#             <sup>
#              2
#             </sup>
#            </span>
#           </span>
#           <span class="separator">
#            ·
#           </span>
#           <span class="priceinfo">
#            $2,150
#           </span>
#           <span class="pic-button">
#            pic
#           </span>
#           <button class="bd-button cl-banish-button icon-only" tabindex="0" title="hide posting" type="button">
#            <span class="icon icom-">
#            </span>
#            <span class="label">
#            </span>
#           </button>
#          </span>
#         </div>
#        </li>
#        <li class="cl-search-result cl-search-view-mode-list" title="Light and Bright! See Photos! Vintage Bldg / Pets Welcome! OPEN HOUSE!">
#         <div class="result-node-wide">
#          <button class="bd-button cl-favorite-button icon-only" tabindex="0" title="add to favorites list" type="button">
#           <span class="icon icom-">
#           </span>
#           <span class="label">
#           </span>
#          </button>
#          <a class="titlestring" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-light-and-bright-see-photos/7574835080.html">
#           Light and Bright! See Photos! Vintage Bldg / Pets Welcome! OPEN HOUSE!
#          </a>
#          <span class="meta">
#           <span class="separator">
#            ·
#           </span>
#           Los Angeles / Westlake District / DTLA
#           <span class="separator">
#            ·
#           </span>
#           <span title="Mon Jan 30 2023 11:48:30 GMT-0800 (Pacific Standard Time)">
#            16 minutes ago
#           </span>
#           <span class="separator">
#            ·
#           </span>
#           <span class="housing-meta">
#            <span class="post-bedrooms">
#             1br
#            </span>
#           </span>
#           <span class="separator">
#            ·
#           </span>
#           <span class="priceinfo">
#            $2,195
#           </span>
#           <span class="pic-button">
#            pic
#           </span>
#           <button class="bd-button cl-banish-button icon-only" tabindex="0" title="hide posting" type="button">
#            <span class="icon icom-">
#            </span>
#            <span class="label">
#            </span>
#           </button>
#          </span>
#         </div>
#        </li>
#        <li class="cl-search-result cl-search-view-mode-list" title="***********NEW BUILT GORGEOUS 4 BEDS 4.5 BATHS 2 STORY HOUSE 2500 SQFT">
#         <div class="result-node-wide">
#          <button class="bd-button cl-favorite-button icon-only" tabindex="0" title="add to favorites list" type="button">
#           <span class="icon icom-">
#           </span>
#           <span class="label">
#           </span>
#          </button>
#          <a class="titlestring" href="https://losangeles.craigslist.org/sfv/apa/d/sun-valley-new-built-gorgeous-beds-45/7583509457.html">
#           ***********NEW BUILT GORGEOUS 4 BEDS 4.5 BATHS 2 STORY HOUSE 2500 SQFT
#          </a>
#          <span class="meta">
#           <span class="separator">
#            ·
#           </span>
#           ************** SUN VALLEY *************
#           <span class="separator">
#            ·
#           </span>
#           <span title="Mon Jan 30 2023 11:48:29 GMT-0800 (Pacific Standard Time)">
#            16 minutes ago
#           </span>
#           <span class="separator">
#            ·
#           </span>
#           <span class="housing-meta">
#            <span class="post-bedrooms">
#             4br
#            </span>
#            <span class="post-sqft">
#             2500ft
#             <sup>
#              2
#             </sup>
#            </span>
#           </span>
#           <span class="separator">
#            ·
#           </span>
#           <span class="priceinfo">
#            $5,995
#           </span>
#           <span class="pic-button">
#            pic
#           </span>
#           <button class="bd-button cl-banish-button icon-only" tabindex="0" title="hide posting" type="button">
#            <span class="icon icom-">
#            </span>
#            <span class="label">
#            </span>
#           </button>
#          </span>
#         </div>
#        </li>
#        <li class="cl-search-result cl-search-view-mode-list" title="******GREAT LOCATION SHERMAN OAKS NEAR VENTURA BLVD 3 BED 2 BATH******">
#         <div class="result-node-wide">
#          <button class="bd-button cl-favorite-button icon-only" tabindex="0" title="add to favorites list" type="button">
#           <span class="icon icom-">
#           </span>
#           <span class="label">
#           </span>
#          </button>
#          <a class="titlestring" href="https://losangeles.craigslist.org/sfv/apa/d/sherman-oaks-great-location-sherman/7583509288.html">
#           ******GREAT LOCATION SHERMAN OAKS NEAR VENTURA BLVD 3 BED 2 BATH******
#          </a>
#          <span class="meta">
#           <span class="separator">
#            ·
#           </span>
#           **************SHERMAN OAKS / NEAR VENTURA BLVD**************
#           <span class="separator">
#            ·
#           </span>
#           <span title="Mon Jan 30 2023 11:48:26 GMT-0800 (Pacific Standard Time)">
#            16 minutes ago
#           </span>
#           <span class="separator">
#            ·
#           </span>
#           <span class="housing-meta">
#            <span class="post-bedrooms">
#             3br
#            </span>
#           </span>
#           <span class="separator">
#            ·
#           </span>
#           <span class="priceinfo">
#            $2,995
#           </span>
#           <span class="pic-button">
#            pic
#           </span>
#           <button class="bd-button cl-banish-button icon-only" tabindex="0" title="hide posting" type="button">
#            <span class="icon icom-">
#            </span>
#            <span class="label">
#            </span>
#           </button>
#          </span>
#         </div>
#        </li>
#        <li class="cl-search-result cl-search-view-mode-list" title="In-Unit Washer/Dryer, Solid Surface Flooring, Pool">
#         <div class="result-node-wide">
#          <button class="bd-button cl-favorite-button icon-only" tabindex="0" title="add to favorites list" type="button">
#           <span class="icon icom-">
#           </span>
#           <span class="label">
#           </span>
#          </button>
#          <a class="titlestring" href="https://losangeles.craigslist.org/sfv/apa/d/santa-clarita-in-unit-washer-dryer/7582059062.html">
#           In-Unit Washer/Dryer, Solid Surface Flooring, Pool
#          </a>
#          <span class="meta">
#           <span class="separator">
#            ·
#           </span>
#           25910 Tournament Rd, Valencia, CA
#           <span class="separator">
#            ·
#           </span>
#           <span title="Mon Jan 30 2023 11:48:23 GMT-0800 (Pacific Standard Time)">
#            16 minutes ago
#           </span>
#           <span class="separator">
#            ·
#           </span>
#           <span class="housing-meta">
#            <span class="post-bedrooms">
#             1br
#            </span>
#            <span class="post-sqft">
#             720ft
#             <sup>
#              2
#             </sup>
#            </span>
#           </span>
#           <span class="separator">
#            ·
#           </span>
#           <span class="priceinfo">
#            $2,290
#           </span>
#           <span class="pic-button">
#            pic
#           </span>
#           <button class="bd-button cl-banish-button icon-only" tabindex="0" title="hide posting" type="button">
#            <span class="icon icom-">
#            </span>
#            <span class="label">
#            </span>
#           </button>
#          </span>
#         </div>
#        </li>
#        <li class="cl-search-result cl-search-view-mode-list" title="2 BD, On-Site Management, La Verne CA">
#         <div class="result-node-wide">
#          <button class="bd-button cl-favorite-button icon-only" tabindex="0" title="add to favorites list" type="button">
#           <span class="icon icom-">
#           </span>
#           <span class="label">
#           </span>
#          </button>
#          <a class="titlestring" href="https://losangeles.craigslist.org/ant/apa/d/san-dimas-bd-on-site-management-la/7582782722.html">
#           2 BD, On-Site Management, La Verne CA
#          </a>
#          <span class="meta">
#           <span class="separator">
#            ·
#           </span>
#           antelope valley
#           <span class="separator">
#            ·
#           </span>
#           <span title="Mon Jan 30 2023 11:48:22 GMT-0800 (Pacific Standard Time)">
#            17 minutes ago
#           </span>
#           <span class="separator">
#            ·
#           </span>
#           <span class="housing-meta">
#            <span class="post-bedrooms">
#             2br
#            </span>
#            <span class="post-sqft">
#             985ft
#             <sup>
#              2
#             </sup>
#            </span>
#           </span>
#           <span class="separator">
#            ·
#           </span>
#           <span class="priceinfo">
#            $2,575
#           </span>
#           <span class="pic-button">
#            pic
#           </span>
#           <button class="bd-button cl-banish-button icon-only" tabindex="0" title="hide posting" type="button">
#            <span class="icon icom-">
#            </span>
#            <span class="label">
#            </span>
#           </button>
#          </span>
#         </div>
#        </li>
#       </ol>
#      </div>
#      <p class="no-results">
#       no results
#      </p>
#      <div class="no-day-pages cl-search-toolbars bottom cl-multi-column" id="search-toolbars-2" style="">
#       <div class="cl-search-paginator">
#        <button class="bd-button cl-first-page icon-only bd-disabled" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          first page
#         </span>
#        </button>
#        <button class="bd-button cl-prev-page icon-only bd-disabled" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          previous page
#         </span>
#        </button>
#        <span class="cl-page-number">
#         1 - 120 of &gt;10,000
#        </span>
#        <button class="bd-button cl-next-page icon-only" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          next page
#         </span>
#        </button>
#        <button class="bd-button cl-last-page icon-only" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          last page
#         </span>
#        </button>
#       </div>
#       <div class="cl-search-day-paginator">
#        <button class="bd-button cl-prev-day-page icon-only" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          previous day
#         </span>
#        </button>
#        <span class="cl-page-date">
#        </span>
#        <button class="bd-button cl-next-day-page icon-only" tabindex="0" type="button">
#         <span class="icon icom-">
#         </span>
#         <span class="label">
#          next day
#         </span>
#        </button>
#       </div>
#      </div>
#      <div class="cl-psa">
#       <a class="bd-anchor text-only aboutFha" href="https://www.craigslist.org/about/FHA" tabindex="0">
#        <span class="label">
#         fair housing
#        </span>
#       </a>
#       <a class="bd-anchor text-only safety" href="https://www.craigslist.org/about/safety" tabindex="0">
#        <span class="label">
#         safety tips
#        </span>
#       </a>
#       <a class="bd-anchor text-only aboutProhibited" href="https://www.craigslist.org/about/prohibited" tabindex="0">
#        <span class="label">
#         prohibited items
#        </span>
#       </a>
#       <a class="bd-anchor text-only aboutRecalledItems" href="https://www.craigslist.org/about/recalled_items" tabindex="0">
#        <span class="label">
#         product recalls
#        </span>
#       </a>
#       <a class="bd-anchor text-only scams" href="https://www.craigslist.org/about/scams" tabindex="0">
#        <span class="label">
#         avoiding scams
#        </span>
#       </a>
#      </div>
#     </div>
#    </main>
#    <footer>
#     <span class="copyright">
#      © 2023 craigslist
#     </span>
#     <a class="bd-anchor" href="https://www.craigslist.org/about/help" tabindex="0">
#      <span class="icon icom-">
#      </span>
#      <span class="label">
#       help
#      </span>
#     </a>
#     <a class="bd-anchor" href="https://www.craigslist.org/about/safety" tabindex="0">
#      <span class="icon icom-">
#      </span>
#      <span class="label">
#       safety
#      </span>
#     </a>
#     <a class="bd-anchor" href="https://www.craigslist.org/about/privacy.policy" tabindex="0">
#      <span class="icon icom-">
#      </span>
#      <span class="label">
#       privacy
#      </span>
#     </a>
#     <a class="bd-anchor" href="https://forums.craigslist.org/?forumID=8" tabindex="0">
#      <span class="icon icom-">
#      </span>
#      <span class="label">
#       feedback
#      </span>
#     </a>
#     <a class="bd-anchor" href="https://www.craigslist.org/about/terms.of.use" tabindex="0">
#      <span class="icon icom-">
#      </span>
#      <span class="label">
#       terms
#      </span>
#     </a>
#     <a class="bd-anchor" href="https://www.craigslist.org/about" tabindex="0">
#      <span class="icon icom-">
#      </span>
#      <span class="label">
#       about
#      </span>
#     </a>
#    </footer>
#   </div>
#   <div id="curtain">
#    <div class="cover">
#    </div>
#    <div class="content">
#     <div class="icom-">
#     </div>
#     <div class="text loading">
#      loading
#     </div>
#     <div class="text reading">
#      reading
#     </div>
#     <div class="text writing">
#      writing
#     </div>
#     <div class="text saving">
#      saving
#     </div>
#     <div class="text searching">
#      searching
#     </div>
#     <div class="text message" id="curtainText">
#     </div>
#     <div class="text unrecoverable">
#      <p>
#       <a href="https://losangeles.craigslist.org/search/apa#" id="cl-unrecoverable-hard-refresh" onclick="location.reload(true);">
#        refresh the page.
#       </a>
#      </p>
#     </div>
#    </div>
#   </div>
#   <script>
#    try {
#             window.onpageshow = function(event) {
#                 if (event.persisted && cl.upTime()>1000 && /iPhone/.test(navigator.userAgent)) {
#                     console.log('reloading');
#                     window.location.reload();
#                 }
#             };
#         } catch(e) {
#         }
#   </script>
#  </body>
# </html>

# %% [markdown]
# Let's look at the output to figure out how to parse it.
#
# Again, this takes some detective work and trial and error. As we saw before, opening up the page in the Develop mode in your web browser is often the simplest way to see the hierarchical tag struture.
#
# It looks like each post is in a `<li>` tag. Moreover, note that it's also in a `class` called `cl-search-result`. Structured data like this make it much easier to scrape! The `find_all()` function takes an optional `class_` argument that can filter by class.

# %%
posts = soup.find_all('li', class_='cl-search-result')

# Note that there are 120 results, which is the number of posts returned on the Craigslist webpage. 
# That's a good sign!
print(len(posts))
# Out:
# 120

# %% [markdown]
# Let's look at a sample post.

# %%
posts[2]
# Out:
# <li class="cl-search-result cl-search-view-mode-list" title="SR- Brand new 2 bed, 2 bath  luxury unit with ROOTOP"><div class="result-node-wide"><button class="bd-button cl-favorite-button icon-only" tabindex="0" title="add to favorites list" type="button"><span class="icon icom-"></span><span class="label"></span></button><a class="titlestring" href="https://losangeles.craigslist.org/wst/apa/d/los-angeles-sr-brand-new-bed-bath/7584176475.html">SR- Brand new 2 bed, 2 bath  luxury unit with ROOTOP</a><span class="meta"><span class="separator">·</span>Hollywood<span class="separator">·</span><span title="Mon Jan 30 2023 11:59:28 GMT-0800 (Pacific Standard Time)">5 minutes ago</span><span class="separator">·</span><span class="housing-meta"><span class="post-bedrooms">2br</span><span class="post-sqft">925ft<sup>2</sup></span></span><span class="separator">·</span><span class="priceinfo">$3,295</span><span class="pic-button">pic</span><button class="bd-button cl-banish-button icon-only" tabindex="0" title="hide posting" type="button"><span class="icon icom-"></span><span class="label"></span></button></span></div></li>

# %% [markdown]
# Again, we could use the Develop mode within a web browser to try and reverse-engineer the structure, although this is a short enough snippet that we can just look at this text.
#
# It looks like the title is in a class called `titlestring`, along with the URL.

# %%
posts[2].find(class_='titlestring')
# Out:
# <a class="titlestring" href="https://losangeles.craigslist.org/wst/apa/d/los-angeles-sr-brand-new-bed-bath/7584176475.html">SR- Brand new 2 bed, 2 bath  luxury unit with ROOTOP</a>

# %% [markdown]
# So the title is in the text, and the URL is an attribute called `href`.

# %%
print(posts[2].find(class_='titlestring').text)
print(posts[2].find(class_='titlestring')['href'])
# Out:
# SR- Brand new 2 bed, 2 bath  luxury unit with ROOTOP
# https://losangeles.craigslist.org/wst/apa/d/los-angeles-sr-brand-new-bed-bath/7584176475.html

# %% [markdown]
# What about the other information? The neighborhood seems to be within a tag called `meta`. Note that `find` just finds the first occurence. `find_all` finds all of them, and returns a list.

# %%
posts[2].find(class_='meta').text
# Out:
# '·Hollywood·5 minutes ago·2br925ft2·$3,295pic'

# %% [markdown]
# This is a bit annoying to separate out, but we can use the dots and split on these using `str.split()`.

# %%
# example
'Splitting this sentence into words'.split()
# Out:
# ['Splitting', 'this', 'sentence', 'into', 'words']

# %%
# example with a separator that isn't a space
'Splitting this sentence into words'.split('i')
# Out:
# ['Spl', 'tt', 'ng th', 's sentence ', 'nto words']

# %% [markdown]
# Here, we want to split on the dot.

# %%
posts[2].find(class_='meta').text.split('·')
# Out:
# ['', 'Hollywood', '5 minutes ago', '2br925ft2', '$3,295pic']

# %%
# it's the second element
posts[2].find(class_='meta').text.split('·')[1]
# Out:
# 'Hollywood'

# %% [markdown]
# The price, number of bedrooms, and square footage are easier to find, as they are in their own dedicated classes.

# %%
print(posts[2].find(class_= 'priceinfo').text)
print(posts[2].find(class_= 'post-bedrooms').text)
print(posts[2].find(class_= 'post-sqft').text)
# Out:
# $3,295
# 2br
# 925ft2

# %% [markdown]
# Now we understand the structure of each page. So we are ready to put all of the posts in a dataframe. We'll do that in the next lecture.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3>Key Takeaways</h3>
# <ul>
#   <li>Scraping unstructured webpages involves more detective work and trial and error.</li>
#   <li>Some will have a consistent format and helpful class codes and html tags. Some won't.</li>
# </ul>
# </div>
